# %% [markdown]
# <a href="https://colab.research.google.com/github/osamazafar980/IoTID20-Data-Binary-Classification/blob/master/IoTID20_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
import matplotlib.pyplot as plt

# %% [markdown]
# **MOUNTING DRIVE AND LOADING DATA SET**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
data =pd.read_csv('/content/drive/My Drive/Datasets/IoTID20.csv')
data
# Out:
#                                           Flow_ID  ...                Sub_Cat
# 0        192.168.0.13-192.168.0.16-10000-10101-17  ...      Mirai-Ackflooding
# 1         192.168.0.13-222.160.179.132-554-2179-6  ...        DoS-Synflooding
# 2          192.168.0.13-192.168.0.16-9020-52727-6  ...           Scan Port OS
# 3          192.168.0.13-192.168.0.16-9020-52964-6  ...  Mirai-Hostbruteforceg
# 4       192.168.0.1-239.255.255.250-36763-1900-17  ...  Mirai-Hostbruteforceg
# ...                                           ...  ...                    ...
# 625778   192.168.0.24-210.89.164.90-56112-8043-17  ...     Mirai-UDP Flooding
# 625779    192.168.0.13-222.131.171.244-554-4570-6  ...        DoS-Synflooding
# 625780     192.168.0.13-192.168.0.16-9020-52739-6  ...           Scan Port OS
# 625781     192.168.0.13-192.168.0.16-9020-49784-6  ...                 Normal
# 625782   192.168.0.13-192.168.0.16-10000-10101-17  ...     Mirai-UDP Flooding
#
# [625783 rows x 86 columns]

# %% [markdown]
# **PREPROCESSING AND CLEANING DATA**

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep]
data=clean_dataset(data)
data = data.to_numpy()

# %% [markdown]
# **LABEL ENCODING**

# %%
np.random.shuffle(data) 
X=data[:,7:83]
Y=data[:,83]
Y[Y=='Anomaly']=0
Y[Y=='Normal']=1
minMax= MinMaxScaler()
X = minMax.fit_transform(X)
std = StandardScaler()
X = std.fit_transform(X)

# %% [markdown]
# **SPLITING DATA**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=1)

# %% [markdown]
# **MODEL**

# %%
model = Sequential(
    [
     Dense(32,activation='relu',input_shape=X_train.shape, kernel_initializer='random_normal'),
     Dense(32,activation='relu', kernel_initializer='random_normal'),
     Dense(32,activation='relu', kernel_initializer='random_normal'),
     Dense(1,activation='sigmoid', kernel_initializer='random_normal'),
    ]
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 419028, 32)        2464
# _________________________________________________________________
# dense_1 (Dense)              (None, 419028, 32)        1056
# _________________________________________________________________
# dense_2 (Dense)              (None, 419028, 32)        1056
# _________________________________________________________________
# dense_3 (Dense)              (None, 419028, 1)         33
# =================================================================
# Total params: 4,609
# Trainable params: 4,609
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **COMPILING AND TRAINING MODEL**

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
X_train = tf.convert_to_tensor(X_train,np.float32)
y_train = tf.convert_to_tensor(y_train,np.float32)
print(X_train.shape)
print(y_train.shape)
history=model.fit(X_train, y_train,epochs=10, batch_size=50)
# Out:
# (419028, 76)
# (419028,)
# Epoch 1/10
# WARNING:tensorflow:Model was constructed with shape (None, 419028, 76) for input Tensor("dense_input:0", shape=(None, 419028, 76), dtype=float32), but it was called on an input with incompatible shape (None, 76).
# WARNING:tensorflow:Model was constructed with shape (None, 419028, 76) for input Tensor("dense_input:0", shape=(None, 419028, 76), dtype=float32), but it was called on an input with incompatible shape (None, 76).
# 8381/8381 [==============================] - 12s 1ms/step - loss: 0.0388 - accuracy: 0.9881
# Epoch 2/10
# 8381/8381 [==============================] - 12s 1ms/step - loss: 0.0384 - accuracy: 0.9882
# Epoch 3/10
# 8381/8381 [==============================] - 12s 1ms/step - loss: 0.0381 - accuracy: 0.9882
# Epoch 4/10
# 8381/8381 [==============================] - 12s 1ms/step - loss: 0.0381 - accuracy: 0.9883
# Epoch 5/10
# 8381/8381 [==============================] - 12s 1ms/step - loss: 0.0378 - accuracy: 0.9882
# Epoch 6/10
# 8381/8381 [==============================] - 12s 1ms/step - loss: 0.0377 - accuracy: 0.9884
# Epoch 7/10
# 8381/8381 [==============================] - 12s 1ms/step - loss: 0.0375 - accuracy: 0.9884
# Epoch 8/10
# 8381/8381 [==============================] - 12s 1ms/step - loss: 0.0375 - accuracy: 0.9884
# Epoch 9/10
# 8381/8381 [==============================] - 12s 1ms/step - loss: 0.0371 - accuracy: 0.9885
# Epoch 10/10
# 8381/8381 [==============================] - 13s 2ms/step - loss: 0.0370 - accuracy: 0.9885

# %% [markdown]
# **EVALUTATING MODEL**

# %%
loss,accuracy = model.evaluate(tf.convert_to_tensor(X_test,np.float32),tf.convert_to_tensor(y_test,np.float32))
print("Loss: ", loss)
print('Accuracy: ',accuracy*100)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 419028, 76) for input Tensor("dense_input:0", shape=(None, 419028, 76), dtype=float32), but it was called on an input with incompatible shape (None, 76).
# 6450/6450 [==============================] - 7s 1ms/step - loss: 0.0389 - accuracy: 0.9883
# Loss:  0.038903459906578064
# Accuracy:  98.83131980895996

# %% [markdown]
# **Visualizing Evaluation**

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()
